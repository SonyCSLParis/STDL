# %%
from STDC import STDC

# %%
# initialize class
stdc = STDC(timeframe='Y', field_names=['id1', 'id2', 'timestamp'], time_type='actual', comparison='absolute')

# %%
stdc.calculate_velocities()
# Out:
#     Node                                                 t1  \
# 0   L1_0  2020-01-01 00:00:00 to 2020-12-31 23:59:59.999...
# 1   L1_1  2020-01-01 00:00:00 to 2020-12-31 23:59:59.999...
# 2   L1_2  2020-01-01 00:00:00 to 2020-12-31 23:59:59.999...
# 3   L1_0  2021-01-01 00:00:00 to 2021-12-31 23:59:59.999...
# 4   L1_1  2021-01-01 00:00:00 to 2021-12-31 23:59:59.999...
# 5   L1_2  2021-01-01 00:00:00 to 2021-12-31 23:59:59.999...
# 6   L1_0  2022-01-01 00:00:00 to 2022-12-31 23:59:59.999...
# 7   L1_1  2022-01-01 00:00:00 to 2022-12-31 23:59:59.999...
# 8   L1_2  2022-01-01 00:00:00 to 2022-12-31 23:59:59.999...
# 9   L1_0  2023-01-01 00:00:00 to 2023-12-31 23:59:59.999...
# 10  L1_1  2023-01-01 00:00:00 to 2023-12-31 23:59:59.999...
# 11  L1_2  2023-01-01 00:00:00 to 2023-12-31 23:59:59.999...
#
#                                                    t2  Velocity
# 0   2021-01-01 00:00:00 to 2021-12-31 23:59:59.999...  0.126543
# ...

# %%
stdc.biadjacency_matrix
# Out:
# id2                                                      L2_0  L2_1  L2_10  \
# id1  timeframe
# L1_0 2020-01-01 00:00:00 to 2020-12-31 23:59:59.9999...   2.0   3.0    6.0
#      2021-01-01 00:00:00 to 2021-12-31 23:59:59.9999...   4.0   0.0    3.0
#      2022-01-01 00:00:00 to 2022-12-31 23:59:59.9999...   1.0   1.0    2.0
#      2023-01-01 00:00:00 to 2023-12-31 23:59:59.9999...   3.0   2.0    5.0
#      2024-01-01 00:00:00 to 2024-12-31 23:59:59.9999...   7.0   3.0    3.0
# L1_1 2020-01-01 00:00:00 to 2020-12-31 23:59:59.9999...   3.0   3.0    1.0
#      2021-01-01 00:00:00 to 2021-12-31 23:59:59.9999...   2.0   2.0    4.0
#      2022-01-01 00:00:00 to 2022-12-31 23:59:59.9999...   6.0   3.0    2.0
#      2023-01-01 00:00:00 to 2023-12-31 23:59:59.9999...   1.0   2.0    1.0
#      2024-01-01 00:00:00 to 2024-12-31 23:59:59.9999...   3.0   1.0    5.0
# L1_2 2020-01-01 00:00:00 to 2020-12-31 23:59:59.9999...   3.0   5.0    5.0
# ...

# %%
stdc.positions
# Out:
# id1                                                                                                     L1_0  \
# timeframe                                               2020-01-01 00:00:00 to 2020-12-31 23:59:59.999999999
# id1  timeframe
# L1_0 2020-01-01 00:00:00 to 2020-12-31 23:59:59.9999...                                           0.000000
#      2021-01-01 00:00:00 to 2021-12-31 23:59:59.9999...                                           0.197112
#      2022-01-01 00:00:00 to 2022-12-31 23:59:59.9999...                                           0.151714
#      2023-01-01 00:00:00 to 2023-12-31 23:59:59.9999...                                           0.280555
#      2024-01-01 00:00:00 to 2024-12-31 23:59:59.9999...                                           0.269557
# L1_1 2020-01-01 00:00:00 to 2020-12-31 23:59:59.9999...                                           0.196303
# ...

# %%
stdc.raw_data
# Out:
#       id1    id2                  timestamp  \
# 0    L1_0  L2_14 2020-01-01 19:53:24.908140
# 1    L1_1  L2_15 2020-01-04 18:00:17.021653
# 2    L1_2   L2_9 2020-01-10 15:22:57.610412
# 3    L1_2   L2_9 2020-01-12 12:06:31.530977
# 4    L1_0  L2_11 2020-01-14 13:25:47.798386
# ..    ...    ...                        ...
# 995  L1_2   L2_9 2024-12-16 08:46:31.909265
# 996  L1_2   L2_4 2024-12-20 21:45:53.518020
# 997  L1_0  L2_13 2024-12-22 17:03:43.332807
# 998  L1_1  L2_10 2024-12-31 01:09:31.741041
# 999  L1_2  L2_17 2024-12-31 20:32:26.210608
#
#                                              timeframe
# 0    2020-01-01 00:00:00 to 2020-12-31 23:59:59.999...
# 1    2020-01-01 00:00:00 to 2020-12-31 23:59:59.999...
# 2    2020-01-01 00:00:00 to 2020-12-31 23:59:59.999...
# 3    2020-01-01 00:00:00 to 2020-12-31 23:59:59.999...
# 4    2020-01-01 00:00:00 to 2020-12-31 23:59:59.999...
# ..                                                 ...
# ...

# %%
stdc.calculate_timeframe()
# Out:
#       id1    id2                  timestamp  \
# 0    L1_0  L2_14 2020-01-01 19:53:24.908140
# 1    L1_1  L2_15 2020-01-04 18:00:17.021653
# 2    L1_2   L2_9 2020-01-10 15:22:57.610412
# 3    L1_2   L2_9 2020-01-12 12:06:31.530977
# 4    L1_0  L2_11 2020-01-14 13:25:47.798386
# ..    ...    ...                        ...
# 995  L1_2   L2_9 2024-12-16 08:46:31.909265
# 996  L1_2   L2_4 2024-12-20 21:45:53.518020
# 997  L1_0  L2_13 2024-12-22 17:03:43.332807
# 998  L1_1  L2_10 2024-12-31 01:09:31.741041
# 999  L1_2  L2_17 2024-12-31 20:32:26.210608
#
#                                              timeframe
# 0    2020-01-01 00:00:00 to 2020-12-31 23:59:59.999...
# 1    2020-01-01 00:00:00 to 2020-12-31 23:59:59.999...
# 2    2020-01-01 00:00:00 to 2020-12-31 23:59:59.999...
# 3    2020-01-01 00:00:00 to 2020-12-31 23:59:59.999...
# 4    2020-01-01 00:00:00 to 2020-12-31 23:59:59.999...
# ..                                                 ...
# ...

# %%
stdc.calculate_biadjacency_matrix()
# Out:
# id2                                                      L2_0  L2_1  L2_10  \
# id1  timeframe
# L1_0 2020-01-01 00:00:00 to 2020-12-31 23:59:59.9999...   2.0   3.0    6.0
#      2021-01-01 00:00:00 to 2021-12-31 23:59:59.9999...   4.0   0.0    3.0
#      2022-01-01 00:00:00 to 2022-12-31 23:59:59.9999...   1.0   1.0    2.0
#      2023-01-01 00:00:00 to 2023-12-31 23:59:59.9999...   3.0   2.0    5.0
#      2024-01-01 00:00:00 to 2024-12-31 23:59:59.9999...   7.0   3.0    3.0
# L1_1 2020-01-01 00:00:00 to 2020-12-31 23:59:59.9999...   3.0   3.0    1.0
#      2021-01-01 00:00:00 to 2021-12-31 23:59:59.9999...   2.0   2.0    4.0
#      2022-01-01 00:00:00 to 2022-12-31 23:59:59.9999...   6.0   3.0    2.0
#      2023-01-01 00:00:00 to 2023-12-31 23:59:59.9999...   1.0   2.0    1.0
#      2024-01-01 00:00:00 to 2024-12-31 23:59:59.9999...   3.0   1.0    5.0
# L1_2 2020-01-01 00:00:00 to 2020-12-31 23:59:59.9999...   3.0   5.0    5.0
# ...

# %%
stdc.calculate_unreduced_positions()
# Out:
# id1                                                                                                     L1_0  \
# timeframe                                               2020-01-01 00:00:00 to 2020-12-31 23:59:59.999999999
# id1  timeframe
# L1_0 2020-01-01 00:00:00 to 2020-12-31 23:59:59.9999...                                           0.000000
#      2021-01-01 00:00:00 to 2021-12-31 23:59:59.9999...                                           0.197112
#      2022-01-01 00:00:00 to 2022-12-31 23:59:59.9999...                                           0.151714
#      2023-01-01 00:00:00 to 2023-12-31 23:59:59.9999...                                           0.280555
#      2024-01-01 00:00:00 to 2024-12-31 23:59:59.9999...                                           0.269557
# L1_1 2020-01-01 00:00:00 to 2020-12-31 23:59:59.9999...                                           0.196303
# ...

# %%
# get relative matrix
stdc.calculate_positions()
# Out:
# id1                                                                                                     L1_0  \
# timeframe                                               2020-01-01 00:00:00 to 2020-12-31 23:59:59.999999999
# id1  timeframe
# L1_0 2020-01-01 00:00:00 to 2020-12-31 23:59:59.9999...                                           0.000000
#      2021-01-01 00:00:00 to 2021-12-31 23:59:59.9999...                                           0.197112
#      2022-01-01 00:00:00 to 2022-12-31 23:59:59.9999...                                           0.151714
#      2023-01-01 00:00:00 to 2023-12-31 23:59:59.9999...                                           0.280555
#      2024-01-01 00:00:00 to 2024-12-31 23:59:59.9999...                                           0.269557
# L1_1 2020-01-01 00:00:00 to 2020-12-31 23:59:59.9999...                                           0.196303
# ...
